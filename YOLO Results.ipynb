# %%
#PARTE 1

# %%
from ultralytics import YOLO
# Instancia del modelo YOLO con los pesos especificados
pesos_yolo = "C:/Users/Johan/Desktop/YoloV8/yolov8n.pt"
model = YOLO(pesos_yolo)
try:
# Realiza la detección de objetos en el flujo de video de la cámara del computador
 results = model(source=0, show=True, conf=0.3, save=True)
except Exception as e:
 print("Ocurrió un error al realizar la detección de objetos:", e)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 1 person, 2 toothbrushs, 109.0ms
# 0: 480x640 1 person, 2 toothbrushs, 149.0ms
# 0: 480x640 1 person, 1 toothbrush, 129.0ms
# 0: 480x640 1 person, 2 toothbrushs, 107.0ms
# 0: 480x640 1 person, 2 toothbrushs, 103.0ms
# 0: 480x640 1 person, 1 toothbrush, 106.0ms
# 0: 480x640 1 person, 105.0ms
# 0: 480x640 1 person, 2 toothbrushs, 108.0ms
# ...

# %%
# PARTE 2

# %%
from ultralytics import YOLO
# Configure the tracking parameters and run the tracker
model = YOLO('yolov8n.pt')
# Define the index of the object you want to track in COCO dataset
# For example, let's say you want to track "car", which has index 2 in COCO dataset
object_index = 2

# Modify the track method to track the specified object index
results = model.track(source="0", conf=0.3, iou=0.5, classes=[object_index], show=True)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 145.0ms
# 0: 480x640 (no detections), 211.6ms
# 0: 480x640 (no detections), 153.0ms
# 0: 480x640 (no detections), 138.0ms
# 0: 480x640 (no detections), 146.0ms
# 0: 480x640 (no detections), 144.0ms
# 0: 480x640 (no detections), 140.0ms
# 0: 480x640 (no detections), 139.0ms
# 0: 480x640 (no detections), 166.0ms
# ...

# %%
# PARTE 3

# %%
import cv2
from ultralytics import YOLO
import numpy as np

# Cargar el modelo YOLO preentrenado
model = YOLO("C:/Users/Johan/Desktop/YoloV8/best.pt")

# Realizar la predicción en una imagen
results = model("C:/Users/Johan/Desktop/YoloV8/CarImages/prueba-multiple.jpg", conf=0.3, iou=0.5)

# Iterar sobre cada resultado en la lista
for result in results:
    # Obtener las coordenadas de los bounding boxes
    boxes = result.boxes.xyxy
    
    # Cargar la imagen
    image = cv2.imread("C:/Users/Johan/Desktop/YoloV8/CarImages/prueba-multiple.jpg")
    
    # Dibujar los bounding boxes en la imagen
    for box in boxes:
        xmin, ymin, xmax, ymax = box[:4] # Obtener las coordenadas del bounding box
        xmin, ymin, xmax, ymax = int(xmin), int(ymin), int(xmax), int(ymax)
        cv2.rectangle(image, (xmin, ymin), (xmax, ymax), (0,255,0), 2)
        cv2.putText(image, 'vehicle', (xmin, ymin - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Mostrar la imagen
    cv2.imshow('Imagenes', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# image 1/1 C:\Users\Johan\Desktop\YoloV8\CarImages\prueba-multiple.jpg: 352x608 9 vehicles, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 608)
